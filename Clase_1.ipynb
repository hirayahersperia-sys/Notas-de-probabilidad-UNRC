# %% [markdown]
# <a href="https://colab.research.google.com/github/hirayahersperia-sys/Notas-de-probabilidad-UNRC/blob/main/Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase **2**

# %% [markdown]
# **Experimento determinista**

# %% [markdown]
# **Logica del area**
#
# ejemplo del área de un círculo

# %%
detrminisa y eseatorio arregklrar
definicion
experimento aleatorio


import sympy

return

# %% [markdown]
# **Experimento aleatorio**
#
# ejemplo con una moneda

# %%
import random

moneda_side = ["aguila","sol"]
def lanzar_moneda():
  return random.choice(moneda_side)
lanzar_moneda()
# Out:
# 'aguila'

# %% [markdown]
# **Experimento aleatorio**
#
# ejemplo con un dado

# %%
import random

cara_dado = ["1","2","3","4","5","6"]
def lanzar_dado():
  return random.choice(cara_dado)
lanzar_dado()
# Out:
# '3'
